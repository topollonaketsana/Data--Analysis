# %% [markdown]
# ## 1. Load Data

# %%
import pandas as pd
import numpy as np

# Core files
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

print(f'Train: {len(train)} customers')
print(f'Test: {len(test)} customers')
print()
print(train.describe())
# Out:
# Train: 8360 customers
# Test: 3584 customers
#
#        next_3m_txn_count
# count        8360.000000
# mean          144.969019
# std           152.156725
# min             1.000000
# 25%            35.000000
# 50%           102.000000
# 75%           201.000000
# max          1794.000000

# %% [markdown]
# ## 2. Explore the Feature Files

# %%
# Transaction history (18M rows - this may take a moment)
txn = pd.read_parquet('transactions_features.parquet')

print(f'Transactions: {len(txn):,} rows, {txn.UniqueID.nunique():,} customers')
print(f'Date range: {txn.TransactionDate.min()} to {txn.TransactionDate.max()}')
# Out:
# Transactions: 18,017,073 rows, 11,944 customers
# Date range: 2012-12-25 00:00:00 to 2015-10-31 00:00:00

# %%
txn.head()
# Out:
#                                UniqueID                             AccountID  \
# 0  d7b4459e-41bc-4ab6-98e4-0bfe01a4dfe5  bc348826-aa16-4b71-a2f7-0a78b9cf84cc
# 1  58c224c1-4f38-440f-9c78-b6d5a818839e  1e2e57bc-1ef7-4f0b-8408-861d34065fd5
# 2  4e0dfceb-7186-4b71-bb0d-0e39baa31979  51e7813b-a259-43b6-940f-feb0c2d8199e
# 3  ed2ef2a9-0947-45e6-8f7b-023e88a79ca5  724cd259-3e5e-400a-b843-0361a8e3f751
# 4  06e8f8b9-f8d4-4ae6-a34c-cfbee38e3b7e  6b5d66ed-caf1-44fd-b649-5774e267dc33
#
#   TransactionDate  TransactionAmount      TransactionTypeDescription  \
# 0      2015-03-25            -926.36  Debit Orders & Standing Orders
# 1      2015-07-10           -3073.38            Transfers & Payments
# 2      2015-08-20              45.68          Interest & Investments
# 3      2015-09-05           -8481.62            Transfers & Payments
# 4      2015-08-28            -936.37            Transfers & Payments
#
#   TransactionBatchDescription  StatementBalance IsDebitCredit  \
# 0     Not Disclosed / Unknown          -1165.74        Credit
# 1              System Defined          22420.41        Credit
# 2              System Defined         120793.44         Debit
# 3              System Defined         143372.10        Credit
# 4              System Defined          59896.47        Credit
#
#   ReversalTypeDescription
# 0                  Manual
# 1                  Manual
# 2                   Sytem
# 3                  Manual
# 4                  Manual

# %%
# Financial snapshots
fin = pd.read_parquet('financials_features.parquet')
print(f'Financials: {len(fin):,} rows, {fin.UniqueID.nunique():,} customers')
print()
print(fin.head())

# %%
# Demographics (one row per customer)
demo = pd.read_parquet('demographics_clean.parquet')
print(f'Demographics: {len(demo):,} rows')
print()
print(demo.head())

# %% [markdown]
# ## 3. Your Work Goes Here
#
# This is where you build your solution. Some things to think about:
#
# - How will you aggregate 18M transaction rows into customer-level features?
# - Which columns are most useful? Which ones need cleaning?
# - How does the prediction window relate to the feature data?
# - What modelling approach will you use?

# %%
# Your feature engineering
# ...

# Your model training
# ...

# Your predictions
# ...

# %% [markdown]
# ## 4. Create a Valid Submission
#
# Your submission must match the format of SampleSubmission.csv exactly.

# %%
submission = pd.read_csv('SampleSubmission.csv')

# Replace this with your actual predictions
submission['next_3m_txn_count'] = train['next_3m_txn_count'].mean()

submission.to_csv('submission.csv', index=False)
print(f'Submission saved: {len(submission)} rows')
print(submission.head())

# %% [markdown]
# ## Local Scoring
#
# You can score your submission locally using the included evaluate.py script:
#
#
#
# Note: PublicReference.csv is only available if you have it for local testing. On Zindi, scoring is automatic.
